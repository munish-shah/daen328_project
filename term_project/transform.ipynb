# %%
# Always include these two lines.
# They allow multiple cell outputs
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# Importing required libraries
import requests  # To make HTTP requests and fetch data from APIs
import pandas as pd  # To store, manipulate, and clean tabular data
import sqlite3  # To interact with an SQLite database for data storage
import json  # To handle JSON data from APIs
import matplotlib.pyplot as plt  # Optional, for data visualization
import os # working with operating system functions


# Display confirmation
print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %%
import pandas as pd

# Load the JSON file into a DataFrame
df = pd.read_json('data/api_data.json')

# Preview the data
print(df.head())
# Out:
#    inspection_id                   dba_name                   aka_name  \
# 0        2616252  ROTI MODERN MEDITERRANEAN  ROTI MODERN MEDITERRANEAN
# 1        2616253     MAGGIE GYROS & CHICKEN     MAGGIE GYROS & CHICKEN
# 2        2616226    FORNO ROSSO ON RANDOLPH    FORNO ROSSO ON RANDOLPH
# 3        2616137   HOOK POINT FISHERIES LLC   HOOK POINT FISHERIES LLC
# 4        2616171          TO KOREAN CUISINE          TO KOREAN CUISINE
#
#     license_ facility_type           risk             address     city state  \
# 0  2594670.0    Restaurant  Risk 1 (High)  1012 W RANDOLPH ST  CHICAGO    IL
# 1  1869774.0    Restaurant  Risk 1 (High)       349 E 47TH ST  CHICAGO    IL
# 2  2358717.0    Restaurant  Risk 1 (High)  1048 W RANDOLPH ST  CHICAGO    IL
# 3  3020919.0           NaN            NaN   4755 S TALMAN AVE  CHICAGO    IL
# 4  2997283.0    Restaurant  Risk 1 (High)     3108 N BROADWAY  CHICAGO    IL
#
#        zip  ...    results   latitude  longitude  \
# 0  60607.0  ...       Pass  41.884426 -87.652690
# 1  60653.0  ...   No Entry  41.809257 -87.617666
# 2  60607.0  ...       Pass  41.884401 -87.654031
# 3  60632.0  ...  Not Ready  41.806770 -87.690339
# 4  60657.0  ...       Pass  41.937940 -87.644477
#
#                                             location  \
# 0  {'latitude': '41.88442576290219', 'longitude':...
# 1  {'latitude': '41.80925659134507', 'longitude':...
# 2  {'latitude': '41.88440110509669', 'longitude':...
# 3  {'latitude': '41.80676958214244', 'longitude':...
# 4  {'latitude': '41.937939792358364', 'longitude'...
#
#    :@computed_region_awaf_s7ux :@computed_region_6mkv_f3dw  \
# 0                         41.0                     14917.0
# 1                         12.0                     21192.0
# 2                         41.0                     14917.0
# 3                         29.0                     22248.0
# 4                         38.0                      4449.0
#
#    :@computed_region_vrxf_vc4k  :@computed_region_bdys_3d7i  \
# 0                         29.0                         63.0
# 1                          4.0                        162.0
# 2                         29.0                         63.0
# 3                         55.0                         85.0
# 4                         57.0                        682.0
#
#    :@computed_region_43wa_7qmu  \
# 0                         46.0
# 1                          9.0
# 2                         46.0
# 3                          3.0
# 4                         25.0
#
#                                           violations
# 0                                                NaN
# 1                                                NaN
# 2  55. PHYSICAL FACILITIES INSTALLED, MAINTAINED ...
# 3                                                NaN
# 4  37. FOOD PROPERLY LABELED; ORIGINAL CONTAINER ...
#
# [5 rows x 22 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290850 entries, 0 to 290849
# Data columns (total 22 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   inspection_id                290850 non-null  int64
#  1   dba_name                     290850 non-null  object
#  2   aka_name                     288406 non-null  object
#  3   license_                     290832 non-null  float64
#  4   facility_type                285615 non-null  object
#  5   risk                         290768 non-null  object
#  6   address                      290850 non-null  object
#  7   city                         290689 non-null  object
#  8   state                        290792 non-null  object
#  9   zip                          290809 non-null  float64
#  10  inspection_date              290850 non-null  object
#  11  inspection_type              290849 non-null  object
#  12  results                      290850 non-null  object
#  13  latitude                     289852 non-null  float64
#  14  longitude                    289852 non-null  float64
#  15  location                     289852 non-null  object
#  16  :@computed_region_awaf_s7ux  289551 non-null  float64
#  17  :@computed_region_6mkv_f3dw  289852 non-null  float64
#  18  :@computed_region_vrxf_vc4k  289551 non-null  float64
#  19  :@computed_region_bdys_3d7i  289808 non-null  float64
#  20  :@computed_region_43wa_7qmu  289551 non-null  float64
#  21  violations                   210100 non-null  object
# dtypes: float64(9), int64(1), object(12)
# memory usage: 48.8+ MB

# %%
df.drop(columns=[
    'location',
    ':@computed_region_awaf_s7ux',
    ':@computed_region_6mkv_f3dw',
    ':@computed_region_vrxf_vc4k',
    ':@computed_region_bdys_3d7i',
    ':@computed_region_43wa_7qmu'
], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 290342 entries, 0 to 290341
# Data columns (total 22 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   inspection_id                290342 non-null  int64
#  1   dba_name                     290342 non-null  object
#  2   aka_name                     287919 non-null  object
#  3   license_                     290324 non-null  float64
#  4   facility_type                285136 non-null  object
#  5   risk                         290260 non-null  object
#  6   address                      290342 non-null  object
#  7   city                         290182 non-null  object
#  8   state                        290284 non-null  object
#  9   zip                          290302 non-null  float64
#  10  inspection_date              290342 non-null  object
#  11  inspection_type              290341 non-null  object
#  12  results                      290342 non-null  object
#  13  latitude                     289349 non-null  float64
#  14  longitude                    289349 non-null  float64
#  15  location                     289349 non-null  object
#  16  :@computed_region_awaf_s7ux  289048 non-null  float64
#  17  :@computed_region_6mkv_f3dw  289349 non-null  float64
#  18  :@computed_region_vrxf_vc4k  289048 non-null  float64
#  19  :@computed_region_bdys_3d7i  289306 non-null  float64
#  20  :@computed_region_43wa_7qmu  289048 non-null  float64
#  21  violations                   209742 non-null  object
# dtypes: float64(9), int64(1), object(12)
# memory usage: 50.9+ MB

# %% [markdown]
# inspection_id

# %%
df = df[df['inspection_type'].notnull()]
print(df['inspection_id'].unique())
# Out:
# [2616252 2616253 2616226 ...   67757   70269   67732]

# %%
# Convert 'inspection_id' to numeric (non-convertible values become NaN)
df['inspection_id'] = pd.to_numeric(df['inspection_id'], errors='coerce')

# Drop rows where 'inspection_id' could not be converted (optional but recommended)
df = df.dropna(subset=['inspection_id'])

# Ensure it's of integer type (optional)
df['inspection_id'] = df['inspection_id'].astype(int)

# Drop duplicates based on 'inspection_id'
df = df.drop_duplicates(subset='inspection_id', keep='first')

# %% [markdown]
# dba_name & aka_name

# %%
df['dba_name'] = df['aka_name'].combine_first(df['dba_name'])

# Fill aka_name with updated dba_name if it's missing
df['aka_name'] = df['aka_name'].fillna(df['dba_name'])

# Make both columns fully uppercase
df['dba_name'] = df['dba_name'].str.upper()
df['aka_name'] = df['aka_name'].str.upper()

# %% [markdown]
# liscene_

# %%
df = df[df['license_'].notnull()]
df = df[df['license_'] != 0]
df['license_'] = pd.to_numeric(df['license_'], errors='coerce', downcast='integer')

# %% [markdown]
# facility_type

# %%
# Remove rows with missing facility_type

# %%
df = df.dropna(subset=['facility_type'])

# %%
import re

def map_facility_type(val):
    if pd.isna(val): return 'unknown'
    val = val.lower()
    if re.search(r'restaurant|restu|restaurant bar', val): return 'restaurant'
    if re.search(r'daycare|after school|children.*services|1023|combo', val): return 'daycare'
    if re.search(r'school|cafeteria|university|college', val): return 'school'
    if re.search(r'grocery|taqueria|butcher', val): return 'grocery store'
    if re.search(r'bakery|pastry', val): return 'bakery'
    if re.search(r'coffee|tea|cafe', val): return 'coffee shop'
    if re.search(r'ice cream|paleteria|frozen dessert|gelato', val): return 'ice cream'
    if re.search(r'tavern|bar|liquor|lounge', val): return 'tavern/bar'
    if re.search(r'mobile|push cart|vending machine', val): return 'mobile vendor'
    if re.search(r'chur|church', val): return 'church'
    if re.search(r'banquet|cater|event|venue', val): return 'event/catering'
    if re.search(r'shared kitchen|commissary', val): return 'shared kitchen'
    if re.search(r'hospital|nursing|rehab|senior|care', val): return 'healthcare'
    if re.search(r'convenience|dollar|store|retail', val): return 'retail store'
    if re.search(r'gym|fitness|health club|nutrition', val): return 'fitness'
    return 'other'

# %%
df['facility_type_clean'] = (
    df['facility_type']
    .str.lower()
    .str.strip()
    .str.replace(r'[-_/]', ' ', regex=True)
)

# %% [markdown]
# risk

# %%
df = df[df['risk'].notnull()]
print("\nUnique risk values:")
print(df['results'].unique())
# Out:
# Unique risk values:
# ['Pass' 'No Entry' 'Fail' 'Pass w/ Conditions' 'Not Ready']

# %% [markdown]
# address

# %% [markdown]
# state

# %%
df = df[df['state'] == 'IL']

# %% [markdown]
# city

# %%
df['city'] = df['city'].str.upper()

# %%
unique_counts = df['city'].value_counts()
print(unique_counts)
# Out:
# city
# CHICAGO         283901
# CCHICAGO            59
# SCHAUMBURG          28
# EVANSTON            21
# MAYWOOD             16
#                  ...
# MORTON GROVE         1
# WHEATON              1
# WILMETTE             1
# WADSWORTH            1
# LANSING              1
# Name: count, Length: 69, dtype: int64

# %%
valid_cities = [
    'Chicago', 'Grayslake', 'Brookfield', 'Skokie', 'Evanston', 'Merrillville',
    'Burbank', 'Evergreen Park', 'Naperville', 'Matteson', 'Berwyn', 'Oak Park',
    'Highland Park', 'Plainfield', 'Western Springs', 'Schaumburg', 'Torrance',
    'Summit', 'Lake Zurich', 'Whiting', 'Glen Ellyn', 'Los Angeles', 'Calumet City',
    'Burnham', 'Oak Lawn', 'Morton Grove', 'Bridgeview', 'Griffith', 'New York',
    'Elmhurst', 'New Holstein', 'Algonquin', 'Niles', 'Lansing', 'Wadsworth',
    'Wilmette', 'Wheaton', 'Rosemont', 'Palos Park', 'Elk Grove Village', 'Cicero',
    'Maywood', 'Lake Bluff', 'Schiller Park', 'Bannockburn', 'Bloomingdale',
    'Norridge', 'Charles A Hayes', 'Chicago Heights', 'Justice', 'Tinley Park',
    'Lombard', 'East Hazel Crest', 'Country Club Hills', 'Streamwood',
    'Bolingbrook', 'Des Plaines', 'Olympia Fields', 'Alsip', 'Blue Island',
    'Glencoe', 'Frankfort', 'Broadview', 'Worth'
]

# %%
from rapidfuzz import process, fuzz
import pandas as pd

def clean_and_standardize_cities(df, valid_cities, threshold=80):
    print("Unique cities before cleaning:")
    print(df['city'].value_counts())

    # Normalize valid cities and create a map
    valid_cities_normalized = [city.lower().strip() for city in valid_cities]
    valid_city_map = dict(zip(valid_cities_normalized, valid_cities))  # e.g., 'morton grove' -> 'Morton Grove'

    # Normalize input city names
    df['city_normalized'] = df['city'].str.lower().str.strip()

    # Safe match function with error handling
    def best_match(city):
        result = process.extractOne(city, valid_cities_normalized, scorer=fuzz.ratio)
        if result:
            match, score, _ = result
            if score >= threshold:
                return valid_city_map[match]
        return None

    # Apply matching
    df['city_cleaned'] = df['city_normalized'].apply(best_match)

    # Filter matched rows
    df_cleaned = df[df['city_cleaned'].notnull()].copy()
    df_cleaned['city'] = df_cleaned['city_cleaned']
    df_cleaned.drop(columns=['city_normalized', 'city_cleaned'], inplace=True)

    print("\nUnique cities after cleaning:")
    print(df_cleaned['city'].value_counts())

    return df_cleaned

# %%
df = clean_and_standardize_cities(df, valid_cities)
# Out:
# Unique cities before cleaning:
# city
# CHICAGO         283901
# CCHICAGO            59
# SCHAUMBURG          28
# EVANSTON            21
# MAYWOOD             16
#                  ...
# MORTON GROVE         1
# WHEATON              1
# WILMETTE             1
# WADSWORTH            1
# LANSING              1
# Name: count, Length: 69, dtype: int64
#
# Unique cities after cleaning:
# city
# Chicago               283996
# Schaumburg                28
# Evanston                  21
# Maywood                   16
# Elk Grove Village         13
# Skokie                     9
# Oak Park                   9
# Cicero                     9
# Elmhurst                   7
# Calumet City               6
# Berwyn                     6
# Summit                     5
# Worth                      5
# Highland Park              4
# Bridgeview                 4
# Naperville                 4
# Charles A Hayes            4
# Plainfield                 4
# Schiller Park              3
# Rosemont                   3
# East Hazel Crest           3
# Alsip                      3
# Burbank                    2
# Blue Island                2
# Oak Lawn                   2
# Streamwood                 2
# Lake Zurich                2
# Evergreen Park             2
# Chicago Heights            2
# Glencoe                    1
# Olympia Fields             1
# Tinley Park                1
# Frankfort                  1
# Bolingbrook                1
# Broadview                  1
# Country Club Hills         1
# Brookfield                 1
# Lombard                    1
# Grayslake                  1
# Des Plaines                1
# Morton Grove               1
# Justice                    1
# Norridge                   1
# Bloomingdale               1
# Matteson                   1
# Lake Bluff                 1
# Western Springs            1
# Glen Ellyn                 1
# Palos Park                 1
# Wheaton                    1
# Burnham                    1
# Wadsworth                  1
# Lansing                    1
# Algonquin                  1
# Wilmette                   1
# Name: count, dtype: int64

# %% [markdown]
# zip

# %%
df = df[df['zip'].notnull()]
df['zip'] = pd.to_numeric(df['zip'], errors='coerce', downcast='integer')

# %% [markdown]
# latitude and longitude

# %%
from mapbox import Geocoder
import pandas as pd
import time
from tqdm import tqdm

# 🔑 Replace this with your own Mapbox access token
MAPBOX_TOKEN = "pk.eyJ1IjoiZW1pbHlqdWFyZXoiLCJhIjoiY205dDVjeHZlMDhhZDJqb3QwanU2YTl3cyJ9.K6u54UVcXIlN7RZFj-cNLQ"
geocoder = Geocoder(access_token=MAPBOX_TOKEN)

# Add a progress bar
tqdm.pandas()

# Helper function to geocode an address
def mapbox_geocode(row):
    if pd.notna(row['latitude']) and pd.notna(row['longitude']):
        return row['latitude'], row['longitude']
    
    address = f"{row['address']}, {row['city']}, {row['state']} {int(row['zip']) if pd.notna(row['zip']) else ''}"
    try:
        response = geocoder.forward(address, limit=1)
        geojson = response.geojson()
        if geojson['features']:
            coords = geojson['features'][0]['geometry']['coordinates']
            # Mapbox returns [longitude, latitude]
            return coords[1], coords[0]
    except Exception as e:
        print(f"Error geocoding: {address} -> {e}")
    
    time.sleep(0.5)  # Throttle just in case
    return None, None

# Filter rows where lat/lon are missing
missing_coords = df[df['latitude'].isna() | df['longitude'].isna()]

# Apply Mapbox geocoding
coords = missing_coords.progress_apply(mapbox_geocode, axis=1)

# Fill in the lat/lon
df.loc[coords.index, ['latitude', 'longitude']] = list(coords)
# Out:
# 100%|██████████| 946/946 [00:24<00:00, 38.53it/s]

# %% [markdown]
# inspection_date

# %%
df['inspection_date'] = pd.to_datetime(df['inspection_date'], format="%Y-%m-%dT%H:%M:%S.%f", errors='coerce')
df['inspection_date'][:3]
# Out:
# 0   2025-04-23
# 1   2025-04-23
# 2   2025-04-23
# Name: inspection_date, dtype: datetime64[ns]

# %% [markdown]
# inspection_type

# %%
df = df[df['inspection_type'].notnull()]

# %% [markdown]
# results

# %%
df = df[df['results'] != 'Out of Business']
df = df[df['results'] != 'Business Not Located']

# %% [markdown]
# violations

# %%
# Extracting the violation number from the violation

df["violations"] = df["violations"].fillna("")
violations_list = []
for violation in df["violations"]:
    violations_list += [violation.split(' | ')]

df["violations_list"] = violations_list
violations_list
# Out:
# [[''],
#  [''],
#  ['55. PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN - Comments: OBSERVED MISSING CEILING TILE PANEL ABOVE DISH MACHINE IN KITCHEN DISHWASH AREA. INSTRUCTED TO REPAIR, REPLACE MISSING PANEL AND MAINTAIN.'],
#  ['37. FOOD PROPERLY LABELED; ORIGINAL CONTAINER - Comments: NOTED DRY INGREDIENTS AND OILS IN KITCHEN ON PREP TABLE, TOP AND BOTTOM SHELVES WITH OUT LABELS. INSTRUCTED TO PROVIDE LABELS OF COMMON NAMES OF ITEMS REMOVED FROM ITS ORIGINAL CONTAINERS. ',
#   '54. GARBAGE & REFUSE PROPERLY DISPOSED; FACILITIES MAINTAINED - Comments: NOTED PILES OF SCRAP WOOD AND DIRT/DEBRIS ON THE GROUND ALONG EXTERIOR WALL OF BUILDING. INSTRUCTED TO REMOVE, CLEAN AND MAINTAIN AREA.'],
#  ['3. MANAGEMENT, FOOD EMPLOYEE AND CONDITIONAL EMPLOYEE; KNOWLEDGE, RESPONSIBILITIES AND REPORTING - Comments: OBSERVED NO WRITTEN EMPLOYEE HEALTH POLICY ON THE PREMISES.INSTRUCTED TO PROVIDE A SIGNED EMPLOYEE HEALTH POLICY FOR EACH EMPLOYEE AND MAINTAIN AS REQUIRED. PRIORITY FOUNDATION VIOLATION 7-38-010.',
#   '10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLIED AND ACCESSIBLE - Comments: OBSERVED NO HAND WASHING SIGN AT HAND SINK NEXT TO THE DISH WASHING AREA IN THE REAR. INSTRUCTED MANAGER TO PROVIDE A SIGN REMINDING ALL EMPLOYEES TO WASH HANDS. ',
#   '38. INSECTS, RODENTS, & ANIMALS NOT PRESENT - Comments: OBSERVED THE REAR WEST DOOR TO THE PARKING LOT TO HAVE A GAP LARGER THAN 1/4 INCH ALONG THE BOTTOM OF BOTH DOORS. INSTRUCTED MANAGER TO PROVIDE DOOR SWEEP AND ADDRESS GAP TO PROTECT AGAINST PESTS.',
#   "38. INSECTS, RODENTS, & ANIMALS NOT PRESENT - Comments: OBSERVED N
',
#   '47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE, PROPERLY DESIGNED, CONSTRUCTED & USED - Comments: OBSERVED MILK CRATES BEING USED AS SHELVING THROUGHOUT THE PREP AND STORAGE AREAS. MUST REMOVE AND PROVIDE SHELVING THAT IS 6" OFF THE FLOOR AND PROVIDES FLOOR ACCESSIBILITY TO ENSURE ADEQUATE FACILITY CLEANING.'],
#  [''],
#  [''],
#  ['16. FOOD-CONTACT SURFACES: CLEANED & SANITIZED - Comments: ALL NOZZLES AND AROUND NOZZLES IN NEED OF DETAIL CLEANING TO REMOVE ALL BUILD UP. INSTRUCTED TO DETAIL CLEAN AND MAINTAIN. ',
#   '39. CONTAMINATION PREVENTED DURING FOOD PREPARATION, STORAGE & DISPLAY - Comments: FRONT AND REAR ICE MACHINES IN NEED OF CLEANING TO REMOVE ALL BUILD UP. INSTRUCTED TO CLEAN AND SANITZE. ',
#   '43. IN-USE UTENSILS: PROPERLY STORED - Comments: ALL ICE UTENSILS MUST BE STORED IN A CLEAN SANITIZED CONTAINER WHEN NOT IN USE. INSTRUCTED TO CORRECT AND MAINTAIN. ',
#   '47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE, PROPERLY DESIGNED, CONSTRUCTED & USED - Comments: ALL CUTTING BOARDS IN NEED OF CLEANING TO REMOVE ALL FOOD DEBRIS  INSTRUCTED TO DETAIL CLEAN AND MAINTAIN ',
#   '49. NON-FOOD/FOOD CONTACT SURFACES CLEAN - Comments: RUBBER GASKETS AT REACH IN COOLERS IN NEED OF CLEANING TO REMOVE ALL BUILD UP. INSTRUCTED TO DETAIL CLEAN AND MAINTAIN ',
#   '49. NON-FOOD/FOOD CONTACT SURFACES CLEAN - Comments: INTERIOR OF REACH IN COOLERS IN NEED OF DETAIL CLEANING TO REMOVE ALL BUILD UP. INSTRUCTED TO DETAIL CLEAN AND MAINTAIN',
#   '55. PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN - Comments: WALL AT FAR END OF FRONT PREP AREA IN NEED OF DETAIL CLEANING TO REMOVE ALL FOOD SPLATTERS AND BUILD UP. INSTRUCTED TO REMOVE ALL CLIPBOARDS AND CLEAN WALL.'],
#  [''],
#  [''],
#  ['38. INSECTS, RODENTS, & ANIMALS NOT PRESENT - Comments: INSTRUCTED TO RODENT PROOF BOTTOM OF REAR (SCREEN DOOR) EXIT DOOR.',
#   '47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE, PROPERLY DESIGNED, CONSTRUCTED & USED - Comments: INSTRUCTED NOT TO USE PLASTIC SODA CRATES OR MILK CRATES AS A MEANS OF ELEVATION IN REAR STORAGE AREA AND INSIDE THE WALK-IN COOLER. MUST USE PROPER RAISED SHELVES 6" OFF THE FLOOR FOR EASY ACCESS ON CLEANING.'],
#  ['35. APPROVED THAWING METHODS USED - Comments: OBSERVED IMPROPER THAWING OF PACKAGE OF SHREDDED CHEESE ON CART IN THE KITCHEN AREA. INSTRUCTED TO THAW PROPERLY.',
#   '40. PERSONAL CLEANLINESS - Comments: OBSERVED FOOD HANDLERS WITHOUT HAIR NETS/RESTRAINTS. INSTRUCTED TO PROVIDE.',
#   '47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE, PROPERLY DESIGNED, CONSTRUCTED & USED - Comments: OBSERVED FOOD ITEMS STORED IN PLASTIC GROCERY BAGS IN THE COLD HOLD UNIT/REFRIGERATOR. INSTRUCTED TO USE PROPER FOOD GRADE STORAGE BAGS AND CONTAINERS ONLY. ',
#   '47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE, PROPERLY DESIGNED, CONSTRUCTED & USED - Comments: OBSERVED MILK CRATES BEING USED AS SHELVING IN THE KITCHEN/FOOD PREP AREA. INSTRUCTED TO REMOVE AND PROVIDE SHELVING THAT IS 6" FROM THE FLOOR TO PROVIDE FLOOR CLEANING ACCESSIBILITY. ',
#   '54. GARBAGE & REFUSE PROPERLY DISPOSED; FACILITIES MAINTAINED - Comments: OBSERVED SURROUNDING AREA AT OUTSIDE DUMPSTER WITH A SMALL AMOUNT OF TRASH AND DEBRIS. INSTRUCTED TO CLEAN AND MAINTAIN. ',
#   '55. PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN - Comments: OBSERVED WATER-STAINED CEILING TILE IN THE EMPLOYEE WASHROOM, IN THE HALLWAY LEADING FROM THE WASHROOM AREA TO THE KITCHEN AND IN THE INFANT CLASSROOM AREAS. INSTRUCTED TO REPLACE AND MAINTAIN.',
#   '56. ADEQUATE VENTILATION & LIGHTING; DESIGNATED AREAS USED - Comments: OBSERVED DIRTY VENT IN THE EMPLOYEE WASHROOM. INSTRUCTED TO CLEAN AND MAINTAIN.'],
#  ['51. PLUMBING INSTALLED; PROPER BACKFLOW DEVICES - Comments: OBSERVED BROKEN BACKFLOW AT MOPSINK FAUCET.  INSTRUCTED TO REPAIR AND MAINTAIN.'],
#  ['55. PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN - Comments: 6-501.11 OBSERVED MISSING AND STAINED CEILING TILES NEAR ICE MACHINE. INSTRUCTED MANAGER TO REPLACE CEILING TILES.',
#   '58. ALLERGEN TRAINING AS REQUIRED - Comments: 2-102.13 OBSERVED CERTIFIED FOOD MANAGER WITH NO FOOD ALLERGEN TRAINING. INSTRUCTED MANAGER TO COMPLY WITH REQUIREMENT.'],
#  ['23. PROPER DATE MARKING AND DISPOSITION - Comments: OBSERVED COLD TCS FOODS (COOKED BLACK BEANS, COOKED POBLANO PEPPERS, SALSA, BURGER SAUCES ETC.) STORED PAST THE 7-DAY MAXIMUM USE BY DATE IN THE PREP COOLERS AND WALK-IN COOLER.  MANAGEMENT INSTRUCTED TO DATE MARK ALL TCS FOODS STORED FOR MORE THAN 24 HOURS IN THE COOLERS AND DISCARD THEM OR USE THEM BY THE USE BY DATE.  PRIORITY VIOLATION 7-38-005.  CITATION ISSUED.',
#   '48. WAREWASHING FACILITIES: INSTALLED, MAINTAINED & USED; TEST STRIPS - Comments: OBSERVED NO IRREVERSIBLE REGISTERING TEMPERATURE INDICATOR ON THE PREMISES TO MEASURE THE SURFACE TEMPERATURE OF UTENSILS BEING WASHED AND SANITIZED INSIDE OF THE HIGH TEMPERATURE DISH MACHINES.  MANAGEMENT INSTRUCTED TO PROVIDE.  PRIORITY FOUNDATION VIOLATION 7-38-005.  ',
#   '57. ALL FOOD EMPLOYEES HAVE FOOD HANDLER TRAINING - Comments: OBSERVED SEVERAL FOOD HANDLING EMPLOYEES WITHOUT A FOOD HANDLER TRAINING CERTIFICATE.  MANAGEMENT INSTRUCTED THAT ALL FOOD HANDLING EMPLOYEES MUST SHOW VALID PROOF OF TRAINING.',
#   '58. ALLERGEN TRAINING AS REQUIRED - Comments: OBSERVED THE CERTIFIED FOOD MANAGER WITHOUT A VALID ALLERGEN TRAINING CERTIFICATE.  MANAGEMENT INSTRUCTED THAT ALL CERTIFIED FOOD MANAGERS MUST SHOW VALID PROOF OF ALLERGEN TRAINING.'],
#  ['55. PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN - Comments: 6-501.11 OBSERVED STAINED CEILING TILES IN REAR DISH/ DINING AREA OF FACILITY. INSTRUCTED MANAGER TO REPLACE STAINED CEILING TILES.'],
#  [''],
#  ['49. NON-FOOD/FOOD CONTACT SURFACES CLEAN - Comments: INSTRUCTED TO CLEAN COOKING EQUIPMENT SURFACES WHERE NEEDED.'],
#  [''],
#  ['47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE, PROPERLY DESIGNED, CONSTRUCTED & USED - Comments: OBSERVED RACKS IN DELI AREA WALK IN COOLER WITH AN ACCUMULATION OF RUST AND DEBRIS BUILD UP. INSTRUCTED TO CLEAN AND REPAINT RACKS OR REPLACE RACKS.'],
#  ['3. MANAGEMENT, FOOD EMPLOYEE AND CONDITIONAL EMPLOYEE; KNOWLEDGE, RESPONSIBILITIES AND REPORTING - Comments: 2-102.14(O) OBSERVED NO EMPLOYEE HEALTH POLICY ON SITE. INSTRUCTED TO PROVIDE. PRIORITY FOUNDATION 7-38-010.',
#   '5. PROCEDURES FOR RESPONDING TO VOMITING AND DIARRHEAL EVENTS - Comments: 2-501.11 OBSERVED NO WRITTEN PROCEDURE NOR ADEQUATE SUPPLIES ON SITE TO RESPOND TO VOMIT AND DIARRHEA EVENTS THAT CAN POTENTIALLY OCCUR INSIDE OF THE MOBILE FOOD PREPARER VEHICLE. INSTRUCTED TO PROVIDE. PRIORITY FOUNDATION 7-38-005.',
#   '50. HOT & COLD WATER AVAILABLE; ADEQUATE PRESSURE - Comments: 5-103.11(B) OBSERVED HOT WATER UNABLE TO MAINTAIN 110F AT THE 3 COMPARTMENT SINK AND 100F AT THE HAND WASHING SINK DURING THE INSPECTION. INSTRUCTED TO MAINTAIN 110F AT THE 3 COMPARTMENT SINK AND 100F AT THE HAND WASHING SINK AT ALL TIMES. PRIORITY VIOLATION 7-38-030(C).'],
#  [''],
#  [''],
#  ['55. PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN - Comments: OBSERVED DEBRIS ON FLOOR AROUND HOT WATER TANK AND GREASE TRAP. INSTRUCTED PERSON IN CHARGE TO CLEAN AND MAINTAIN.'],
#  ['39. CONTAMINATION PREVENTED DURING FOOD PREPARATION, STORAGE & DISPLAY - Comments: OBSERVED ICE BUCKETS HANGING OFF OF EXPOSED PIPES IN BASEMENT NEXT TO ICE MACHINE USED FOR CONSUMPTION. DO NOT HANG ICE BUCKETS FROM CEILING PIPES AND STORE BUCKETS SO THAT CONAMINANTS CAN NOT FALL INTO BUCKET.'],
#  [''],
#  ['47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE, PROPERLY DESIGNED, CONSTRUCTED & USED - Comments: OBSERVED CUTTING BOARD IN FRONT PREP AREA ATTACHED TO COLD HOLD UNIT WITH DEEP CUTS AND MARKS. INSTRUCTED PERSON IN CHARGE TO REPLACE OR RESURFACE.',
#   '55. PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN - Comments: OBSERVED SPILLAGE AND LITTER UNDER SINK IN FRONT PREP AREA. INSTRUCTED PERSON IN CHARGE TO CLEAN AND MAINTAIN.'],
#  [''],
#  ['3. MANAGEMENT, FOOD EMPLOYEE AND CONDITIONAL EMPLOYEE; KNOWLEDGE, RESPONSIBILITIES AND REPORTING - Comments: OBSERVED NO WRITTEN EMPLOYEE HEALTH POLICY ON THE PREMISES.INSTRUCTED MANAGEMENT TO PROVIDE A SIGNED EMPLOYEE HEALTH POLICY FOR EACH EMPLOYEE AND MAINTAIN AS REQUIRED.PRIORITY FOUNDATION VIOLATION 7-38-010.',
#   '5. PROCEDURES FOR RESPONDING TO VOMITING AND DIARRHEAL EVENTS - Comments: NO PROCEDURE/PLAN FOR RESPONDING TO VOMITING AND DIARRHEAL EVENTS.INSTRUCTED TO PROVIDE AND MAINTAIN REQUIRED PROCEDURE/PLAN AND APPROPRIATE SUPPLIES OR KIT. (NECESSARY ITEMS AT A MINIMUM: GLOVES, FACE MASKS, DISPOSABLE MOPS AND APPROPRIATE SANITIZER/SPRAY THAT IS EFFECTIVE AGAINST NOROVIRUS).PRIORITY FOUNDATION VIOLATION 7-38-005.',
#   '16. FOOD-CONTACT SURFACES: CLEANED & SANITIZED - Comments: OBSERVED A SLIGHT DEBRIS ACCUMULATION ENCRUSTED ON THE INTERIOR OF THE ICE MACHINE.MUST REMOVE DEBRIS, DETAIL CLEAN INSIDE ICE MACHINE/HAVE SERVICED AND MAINTAIN ICE MACHINE AT ALL TIMES.  ',
#   '38. INSECTS, RODENTS, & ANIMALS NOT PRESENT - Comments: OBSERVED GAP OPENING APPROX:1/4" INCH AT BOTTOM LEFT CORNER OF REAR KITCHEN EXIT DOOR.INSTRUCTED TO MAKE DOOR TIGHT FITTING ALL ACROSS THE BOTTOM OF DOOR TO PREVENT PEST ENTRY AND MAINTAIN.',
#   '47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE, PROPERLY DESIGNED, CONSTRUCTED & USED - Comments: OBSERVED RAW WOOD SHELVES IN THE REAR DRY STORAGE AREA.INSTRUCTED TO PAINT OR SEAL THE SHELVES ALSO, OBSERVED RUST ON THE WIRE STORAGE RACKS INSIDE THE STAND-UP-COOLER DIRECTLY ACROSS THE 3-COMPARTMENT SINK.INSTRUCTED TO REMOVE RUST AND REPAINT OR REPLACE THE SHELVES. ',
#   '49. NON-FOOD/FOOD CONTACT SURFACES CLEAN - Comments: INSTRUCTED TO DETAIL CLEAN THE GREASE BUILDUP INSIDE OF THE DEEP FRYER AND UNDERNEATH THE COOKING FLAT TOP GRILL AND MAINTAIN.',
#   '51. PLUMBING INSTALLED; PROPER BACKFLOW DEVICES - Comments: OBSERVED LOOSE FAUCET HANDLES IN MEN AND WOMEN WASHROOMS.INSTRUCTED TO REPAIR PLUMBING ISSUES AND MAINTAIN.'],
#  ['2. CITY OF CHICAGO FOOD SERVICE SANITATION CERTIFICATE - Comments: OBSERVED NO VALID CITY OF CHICAGO SANITATION CERTIFICATE ON SITE. CITY OF CHICAGO SANITATION CERTIFICATE ON SITE IS EXPIRED. INSTRUCTED PERSON IN CHARGE TO OBTAIN NEW SANITATION TRAINING AND CERTIFICATE AND RETAIN ON SITE. PRIORITY FOUNDATION #7-38-012. CITATION ISSUED. ',
#   '55. PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN - Comments: OBSERVED BUILD UP OF DEBRIS UNDER BAR AREA. INSTRUCTED PERSON IN CHARGE TO CLEAN AND MAINTAIN.'],
#  ['3. MANAGEMENT, FOOD EMPLOYEE AND CONDITIONAL EMPLOYEE; KNOWLEDGE, RESPONSIBILITIES AND REPORTING - Comments: OBSERVED NO WRITTEN EMPLOYEE HEALTH POLICY ON THE PREMISES.  MANAGEMENT INSTRUCTED TO HAVE A SIGNED EMPLOYEE HEALTH POLICY FOR ALL EMPLOYEES.  PRIORITY FOUNDATION VIOLATION 7-38-010.  ',
#   '5. PROCEDURES FOR RESPONDING TO VOMITING AND DIARRHEAL EVENTS - Comments: OBSERVED NO CLEA
],
#  ['3. MANAGEMENT, FOOD EMPLOYEE AND CONDITIONAL EMPLOYEE; KNOWLEDGE, RESPONSIBILITIES AND REPORTING - Comments: OBSERVED NO VERIFIABLE EMPLOYEE HEALTH POLICY ON SITE. LEFT TEMPLATE AND INSTRUCTED TO MAINTAIN COPIES OF EMPLOYEE HEALTH POLICY SIGNED BY ALL EMPLOYEES ON SITE AT ALL TIMES. PRIOIRTY FOUNDATION VIOLATION 7-38-010. NO CITATION ISSUED.',
#   '33. PROPER COOLING METHODS USED; ADEQUATE EQUIPMENT FOR TEMPERATURE CONTROL - Comments: OBSERVED 1 DELI DISPLAY CASE COOLER MAINTAINING IMPROPER AMBIENT TEMPERATURE OF 51.0F. COOLER TAGGED AND HELD FOR INSPECTION. INSTRUCTED TO REPAIR OR REPLACE AND MAINTAIN COOLER SO THAT IT MAINTAINS PROPER AMBIENT TEMPERATURE OF 41F OR BELOW. PRIORITY VIOLATION 7-38-005. NO CITATION ISSUED.',
#   '57. ALL FOOD EMPLOYEES HAVE FOOD HANDLER TRAINING - Comments: OBSERVED NO FOOD HANDLER CERTIFICATES ON SITE AT TIME OF INSPECTION. INSTRUCTED ALL FOOD EMPLOYEES MUST COMPLETE FOOD HANDLER TRAINING AND MAINTAIN RECORDS THEREOF ON SITE AT ALL TIMES.'],
#  ['45. SINGLE-USE/SINGLE-SERVICE ARTICLES: PROPERLY STORED & USED - Comments: OBSERVED SINGLE SERVICE UTENSILS STORED IMPROPERLY FOR CUSTOMER SELF SERVICE. STORE SINGLE SERVICE UTENSILS WITH HANDLES FACING OUT IN ORDER TO PREVENT CONTAMINATION.'],
#  ['38. INSECTS, RODENTS, & ANIMALS NOT PRESENT - Comments: OBSERVED A 1/4" GAP UNDERNEATH THE FRONT DOOR. MUST PROVIDE AND MAINTAIN A PROPER WEATHER STRIP TO PREVENT POSSIBLE ENTRY POINT FOR PEST.',
#   '49. NON-FOOD/FOOD CONTACT SURFACES CLEAN - Comments: MUST CLEAN AND MAINTAIN THE COUNTER TOP UNDERNEATH THE COFFEE MACHINE. MUST CLEAN THE INTERIOR OF REFRIGERATORS AND DEFROST AND CLEAN THE INTERIOR OF DEEP FREEZER IN THE BASEMENT.',
#   '55. PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN - Comments: FLOORS AND SHELVING NEED DETAIL CLEANING UNDER SERVICE COUNTER TO REMOVE DEBRIS.',
#   '60. PREVIOUS CORE VIOLATION CORRECTED - Comments: OBSERVED PREVIOUS CORE VIOLATION #58: ALLERGEN TRAINING NOT CORRECTED AS REQUIRED. PRIORITY FOUNDATION CITATION ISSUED #7-42-090. Violation Codes: 2-102.13 Inspector Comments: OBSERVE THE CERTIFIED MANAGER ON DUTY WITHOUT HER ALLERGEN TRAINING AS REQUIRED.'],
#  ['10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLIED AND ACCESSIBLE - Comments: OBSERVED NO HANDWASHING SIGNAGE AT THE HANDWASHING SINKS IN THE REAR PREP AREA AND IN THE TOILET ROOM NEAR THE FOOD PREP AREA. INSTRUCTED TO PROVIDE AND MAINTAIN.',
#   '36. THERMOMETERS PROVIDED & ACCURATE - Comments: OBSERVED NO AMBIENT AIR THERMOMETER IN THE REFRIGERATORS IN THE BASEMENT. INSTRUCTED TO PROVIDE AND MAINTAIN.',
#   '48. WAREWASHING FACILITIES: INSTALLED, MAINTAINED & USED; TEST STRIPS - Comments: OBSERVED ONE SINK STOPPER MISSING FOR THE THREE COMPARTMENT SINK. INSTRUCTED TO PROVIDE AND MAINTAIN.',
#   '55. PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN - Comments: OBSERVED THE BLUE WALLS IN THE REAR OF THE FOOD PREP AREA WITH FOOD SPLATTERS. INSTRUCTED TO CLEAN AND MAINTAIN.',
#   '56. ADEQUATE VENTILATION & LIGHTING; DESIGNATED AREAS USED - Comments: OBSERVED TWO BLOWN OUT LIGHT BULBS ABOVE THE HANDWASHING SINK IN THE REAR FOOD PREP AREA. INSTRUCTED TO CLEAN AND MAINTAIN.'],
#  ['56. ADEQUATE VENTILATION & LIGHTING; DESIGNATED AREAS USED - Comments: OBSERVED BUILD UP OF DUST/GREASE ON FILTERS IN HOOD VENTILATION SYSTEM IN HOT PREP AREA. INSTRUCTED PERSON IN CHARGE TO CLEAN AND MAINTAIN.'],
#  ['49. NON-FOOD/FOOD CONTACT SURFACES CLEAN - Comments: OBSERV
',
#   '56. ADEQUATE VENTILATION & LIGHTING; DESIGNATED AREAS USED - Comments: OBSERVED BURNED OUT LIGHT BULBS IN FROM PREP AREA. INSTRUCTED TO REPLACE BULBS TO MAINTAIN PROPER LIGHTING INTENSITY.'],
#  ['55. PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN - Comments: OBSERVED BUILD UP OF DEBRIS IN FLOOR DRAINS. INSTRUCTED PERSON IN CHARGE TO CLEAN AND MAINTAIN.'],
#  ['39. CONTAMINATION PREVENTED DURING FOOD PREPARATION, STORAGE & DISPLAY - Comments: FOOD STORAGE ON FLOOR IN WALK IN FREEZER. INSTD TO ELEVATE 6 INCHES AND MAINTAIN'],
#  ["59. PREVIOUS PRIORITY FOUNDATION VIOLATION CORRECTED - Comments: 8-404.13 (B)(3) PREVIOUS PRIORITY FOUNDATION VIOLATION FROM REPORT #2615534 ON 4/10/25 NOT CORRECTED: 38 - OBSERVED EVIDENCE OF RODENT ACTIVITY ON THE PREMISES. OBSERVED APPROX. 140 MOUSE DROPPINGS IN THE FOLLOWING AREAS: 5 DROPPINGS ON THE FLOOR OF THE LUNCHROOM IN THE CORNERS, 10 DROPPINGS IN THE STORAGE CABINET AND ON THE FLOOR IN ROOM 201, 30 DROPPINGS ON THE SHELVES AND CABINETS AND ON THE FLOOR BEHIND THE CABINETS IN ROOM 206, 35 DROPPINGS IN THE MAIN OFFICE VAULT ON THE FLOOR AND STORAGE SHELVES, ON THE FLOOR IN THE ASSISTANT PRINCIPAL'S OFFICE AND IN THE SECRETARY'S OFFICE, 20 DROPPINGS ON THE FLOOR IN ROOM 101, 20 DROPPINGS ON THE SHELVES IN THE OFFICE IN THE BACK CORNER OF MEDIA ROOM 103 AND THE MDF ROOM, AND 20 DROPPINGS ON THE STORAGE SHELVES IN MUSIC ROOM 110 STORAGE CLOSET . ADDITIONAL PEST CONTROL SERVICE IS NEEDED TO ELIMINATE THE PEST ACTIVITY. MANAGEMENT INSTRUCTED TO CLEAN AND REMOVE ALL RODENT DROPPINGS FROM ALL AFFECTED AREAS. PRIORITY VIOLATION 7-42-090."],
#  [''],
#  ['51. PLUMBING INSTALLED; PROPER BACKFLOW DEVICES - Comments: REPAIR THE LEAK AT THE MIDDLE COMPARTMENT OF THE 3-COMPARTMENT SINK IN THE DISHROOM.'],
#  ['43. IN-USE UTENSILS: PROPERLY STORED - Comments:  3-304.12 : OBSERVED A BOWLS STORED INSIDE DRY BEANS,LONG HANDLE LADLES STORED DOWN INSIDE OF FOOD IN DRAWER COOLER AT GRILL MUST REMOVE AND STORE PROPERLY.',
#   '47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE, PROPERLY DESIGNED, CONSTRUCTED & USED - Comments: 4-501.12 : MUST REPAIR OR REPLACE STAINED CUTTING BOARDS.',
#   '47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE, PROPERLY DESIGNED, CONSTRUCTED & USED - Comments: 4-101.19 : MUST REMOVE CARDBOARD FROM WALK IN COOLER SHELVING UNIT.',
#   '55. PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN - Comments: 6-501.114 : MUST ELEVATE ARTICLES OFF OF FLOOR AND AWAY FROM WALLS IN FRONT PREP AREA UNDER SERVICE COUNTER AND STORE PROPERLY.'],
#  ['55. PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN - Comments: OBSERVED DAMAGE AROUND WINDOWSILL ABOVE THREE COMPARTMENT SINK. INSTRUCTED PERSON IN CHARGE TO REPAIR AND MAINTAIN. ',
#   '55. PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN - Comments: OBSERVED ITEMS STORED ON FLOOR IN STORAGE ROOM NEAR REAR EXTERIOR DOOR. INSTRUCTED PERSON IN CHARGE TO ELEVATE ALL ITEMS AT LEAST SIX INCHES FROM THE FLOOR AT ALL TIMES.'],
#  ['44. UTENSILS, EQUIPMENT & LINENS: PROPERLY STORED, DRIED, & HANDLED - Comments
',
#   '55. PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN - Comments: OBSERVED CLUTTER IN REAR STORAGE, UTILITY AND BASEMENT AREAS. INSTRUCTED MANAGER TO REMOVA ALL UNNECESSARY ARTICLES, ORGANIZE AND MAINTAIN ALL AREAS.'],
#  [''],
#  ['38. INSECTS, RODENTS, & ANIMALS NOT PRESENT - Comments: MUST REPAIR OR REPLACE GAP ALONG BOTTOM OF GARBAGE DOOR AND CLASS ROOM 120A EXIT DOOR.',
#   '44. UTENSILS, EQUIPMENT & LINENS: PROPERLY STORED, DRIED, & HANDLED - Comments: MUST INVERT MULTI-USE UTENSILS ON DISH STORAGE SHELVES.',
#   '55. PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN - Comments: MUST SCRAPE CHIPPING PAINT FROM WALLS IN CLASS ROOM 104,107,122C.'],
#  ['49. NON-FOOD/FOOD CONTACT SURFACES CLEAN - Comments: OBSERVED CABINET UNDER SINK (TALLBOY TACO) WITH DEBRIS AND SOILED TOWELS. INSTRUCTD PERSON IN CHARGE TO CLEAN AND MAINTAIN. ',
#   '52. SEWAGE & WASTE WATER PROPERLY DISPOSED - Comments: OBSERVED GREASE TRAP(S) LOCATED AT HIGH TEMP DISH MACHINE IN REAR WITH EXCESSIVE RUST AND BUILD UP OF GREASE ON EXTERIOR. INSTRUCTED PERSON IN CHARGE TO CLEAN/REPAIR OR REPLACE. ',
#   '58. ALLERGEN TRAINING AS REQUIRED - Comments: OBSERVED NO ALLERGEN TRAINING CERTIFICATE ON SITE FOR CERTIFIED MANAGER. INSTRUCTED TO OBTAIN TRAINING AND RETAIN CERTIFICATE ON SITE.'],
#  ['49. NON-FOOD/FOOD CONTACT SURFACES CLEAN - Comments: OBSERVED SLIGHT GREASE DROPLETS ON THE VENTILATION HOOD ABOVE THE DEEP FRYERS AND FLAT TOP GRILL IN THE MAIN PREP AREA. INSTRUCTED TO CLEAN AND MAINTAIN.',
#   '58. ALLERGEN TRAINING AS REQUIRED - Comments: OBSERVED NO ALLERGEN TRAINING CERTIFICATE FOR THE CERTIFIED FOOD MANAGER ON SITE AT THE TIME OF THE INSPECTION. INSTRUCTED ALL FOOD MANAGERS MUST TAKE COURSE AND KEEP RECORDS ON SITE AT ALL TIMES.'],
#  ['38. INSECTS, RODENTS, & ANIMALS NOT PRESENT - Comments: OBSERVED THE FOLLOWING DOORS NOT RODENT-PROOFED, 1/4" GAP AT RIGHT CORNER OF LEFT DOOR AT LEARN MAIN ENTRANCE DOOR, 1/2" GAP BETWEEN DOUBLE DOORS NEAR EXIT #2, 1/4" GAP AT BOTTOM CORNERS OF EMERGENCY EXIT DOOR NEAR ROOM 100. INSTRUCTED MANAGER TO SEAL ALL OUTER OPENINGS ON DOORS TO PREVENT PEST ENTRY.',
#   '39. CONTAMINATION PREVENTED DURING FOOD PREPARATION, STORAGE & DISPLAY - Comments: OBSERVED FOOD ITEMS STORED ON FLOOR IN DRY FOOD STORAGE AREA. INSTRUCTED MANAGER TO ELEVATE ALL FOOD ITEMS SIX INCHES OFF FLOOR.',
#   '47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE, PROPERLY DESIGNED, CONSTRUCTED & USED - Comments: OBSERVED MILK CRATES USED AS SHELVING INSIDE WALK-IN FREEZER. INSTRUCTED MANAGER TO PROVIDE ADEQUATE SHELVING FOR STORAGE.',
#   '51. PLUMBING INSTALLED; PROPER BACKFLOW DEVICES - Comments: OBSERVED LEAKING FAUCETS ON 3-COMPARTMENT SINK. OBSERVED NO RUNNING WATER AT LEFT SINK IN BOYS LOWER-LEVEL WASHROOM. OBSERVED LEAKING VALVE UNDER HAND WASHING SINK IN FIRST FLOOR STAFF WASHROOM. INSTRUCTED MANAGER TO REPAIR AND MAINTAIN.',
#   '53. TOILET FACILITIES: PROPERLY CONSTRUCTED, SUPPLIED, & CLEANED - Comments: OBSERVED NO COVERED RECEPTACLES IN SECOND FLOOR STAFF LOUNGE WASHROOM AND LOWER-LEVEL THORP GIRLS WASHROOM. INSTRUCTED MANAGER TO PROVIDE COVERED RECEPTACLES IN ALL GIRLS, WOMEN AND UNISEX WASHROOMS.',
#   '53. TOILET FACILITIES: PROPERLY CONSTRUCTED, SUPPLIED, & CLEANED - Comments: OBSERVED MISSING LAST STALL DOOR IN THORP LOWER-LEVEL GIRLS WASHROOM. INSTRUCTED MANGER TO REPLACE AND MAINTAIN.',
#   '55. PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN - Comments: OBSERV
. WIPING CLOTHS: PROPERLY USED & STORED - Comments: ALL WIPING CLOTHS MUST BE KEPT IN A CLEAN SANITING SOLUTION WHENNOT IN USE. CORRECT AND MAINTAIN AT ALL TIMES. ',
#   '47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE, PROPERLY DESIGNED, CONSTRUCTED & USED - Comments: CUTTING BOARDS IN FRUIT PROCESSING ROOM IN NEED OF REPLACING. WORN, DISCOLORED. INSTRUCTED TO CORRECT AND MAINTAIN. ',
#   '47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE, PROPERLY DESIGNED, CONSTRUCTED & USED - Comments: DELI WINDOW IN NEED OF REPAIR. MISSING HANDLE. INSTRUCTED TO CORRECT AND MAINTAIN ',
#   '49. NON-FOOD/FOOD CONTACT SURFACES CLEAN - Comments: ALL COOKING EQUIPMENT IN DELI AREA AND BAKERY AREA IN NEED OF CLEANING TO REMOVE ALL FOOD BUILD UP.AND SPLATTER. INSTRUCTED TO DETAIL CLEAN AND MAINTAIN. ',
#   '49. NON-FOOD/FOOD CONTACT SURFACES CLEAN - Comments: ALL PREP TABLES, TABLE LEGS AND WHEELS IN FRUIT PROCESSING ROOM, DELI AND BAKERY IN NEED OF DETAIL CLEANING TO REMOVE ALL BUILD UP OF SPLATTER. INSTRUCTED TO DETAIL CLEAN AND MAINTAIN. ',
#   '55. PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN - Comments: FLOORS IN NEED OF DETAIL CLEANING UNDER ALL EQUIPMENT, PREP TABLES, AND 3 COMP SINKS IN BAKERY, DELI, AND FRUIT PROCESSING AREA. INSTRUCTED TO DETAIL CLEAN AND MAINTAIN',
#   '55. PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN - Comments: WALLS AND COVING IN NEED OF DETAIL CLEANING IN BAKERY, DELI AND PRODUCE SERVICE AREAS TO REMOVE ALL SPLATTER AND BUILD UP. INSTRUCTED TO DETAIL CLEAN AND MAINTAIN. ',
#   '56. ADEQUATE VENTILATION & LIGHTING; DESIGNATED AREAS USED - Comments: AIR VENTS IN BAKERY AND DELI AREA IN NEED OF DETAIL CLEANING TO REMOVE ALL DUST BUILD UP ON VENT AND CEIL TILES. INSTRUCTED TO DETAIL CLEAN AND MAINTAIN'],
#  ['36. THERMOMETERS PROVIDED & ACCURATE - Comments: MISSING THERMOMETERS FOR COOLERS AT FRONT PRPER AREA. INSTD TO PROVIDE AND MAINTAIN',
#   '37. FOOD PROPERLY LABELED; ORIGINAL CONTAINER - Comments: DRY STORAGE CONTAINERS NOT LABELED WITH COMMON NAME. INSTD TO LABEL WITH COMMON NAME AND MAINTAIN',
#   '56. ADEQUATE VENTILATION & LIGHTING; DESIGNATED AREAS USED - Comments: MISSING LIGHTSHIELD FOR LIGHT IN WAREWASHING AREA. INSTD TO PROVIDE LIGHTSHIELD AND MAINTAIN'],
#  [''],
#  [''],
#  ['38. INSECTS, RODENTS, & ANIMALS NOT PRESENT - Comments: OBSERVED OVER 40 RODENT (MICE) DROPPINGS UNDERNEATH DISPLAY SHELVES (AISLE 5, 6, 7, 8), OVER 20 MICE DROPPINGS BEHIND DISPLAY SHELVES (CEREAL, BREAD, NUTS SHELVES) AND OVER 20 MICE DROPPINGS IN FRONT/UNDERNEATH CANDY SHELVES. INSTRUCTED TO REMOVE, CLEAN AND SANITIZE THE AFFECTED AREAS. MUST DETAIL CLEAN AND MAINTAIN FLOOR UNDER DISPLAY SHELVES WITH DRIED FOOD DEBRIS. RECOMMEND TO CONTACT LICENSED PEST CONTROL FOR SERVICE. (PEST CONTROL SERVICING BUSINESS WEEKLY)                                                                                 PRIORITY FOUNDATION VIOLATION 7-38-020 (A)        CITATION ISSUED',
#   '47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE, PROPERLY DESIGNED, CONSTRUCTED & USED - Comments: 4-101.19  INSTRUCTED NOT TO USE MILK CRATES AS A MEANS OF ELEVATION THROUGHOUT (BAKERY/DELI/SUSHI/MEAT/SEAFOOD PREP ETC FOR EASY ACCESS ON CLEANING.',
#   '55. PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN - Comments: 6-201.13  INSTRUCTED TO SEAL HOLES ON WALL AROUND PREP AREAS TO PREVENT PEST HARBORAGE. ',
#   '55. PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN - Comments: 6-201
INSTRUCTED MANAGER TO REPAIR AND MAINTAIN.',
#   '56. ADEQUATE VENTILATION & LIGHTING; DESIGNATED AREAS USED - Comments: OBSERVED NO LIGHTING IN WALK-IN COOLER AND FREEZER. INSTRUCTED MANAGER TO PROVIDE ADEQUATE LIGHTING AND MAINTAIN.',
#   '60. PREVIOUS CORE VIOLATION CORRECTED - Comments: PREVIOUS CORE VIOLATIONS NOT CORRECTED FROM REPORT #2605791 ON 11-1-24:39-OBSERVED NO SPLASH GUARD BETWEEN HAND WASHING SINK AND PREP SINK. INSTRUCTED MANAGER TO PROVIDE. 58- OBSERVED NO ALLERGEN TRAINING FOR CERTIFIED MANAGERS. ALL CERTIFIED MANAGERS MUST PROVIDE ALLERGEN TRAINING. PRIORITY FOUNDATION 7-42-090 CITATION ISSUED'],
#  ['49. NON-FOOD/FOOD CONTACT SURFACES CLEAN - Comments: MUST CLEAN AND MAINTAIN THE INTERIOR OF THE WALK IN AND REACH IN COOLERS. MUST REMOVE BLACK SUBSTANCE FROM THE CEILING, FAN COVERS AND SHELVING.',
#   '55. PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN - Comments:  OBSERVED BROKEN, MISSING AND WATER STAINED CEILING TILES THROUGHOUT THE FACILITY. INSTRUCTED MANAGER TO REPLACE/CLEAN AND MAINTAIN IN GOOD REPAIR.'],
#  ['36. THERMOMETERS PROVIDED & ACCURATE - Comments: NO METAL STEM PROBE THERMOMETER ON THE PREMISES CAPABLE OF TAKING HOT AND COLD FOOD TEMPERATURES. INSTRUCTED TO PROVIDE A THERMOMETER TO TAKE HOT AND COLD FOOD TEMPERATURES. PRIORITY FOUNDATION VIOLATION, 7-38-005. CITATION ISSUED.',
#   '47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE, PROPERLY DESIGNED, CONSTRUCTED & USED - Comments: OBSERVED ALUMINUM FOIL BEING USED AS A LINER AT THE BOTTOM OF BEVERAGE COOLER IN THE FRONT WAIT AREA. INSTRUCTED TO REMOVE OR REPLACE WITH A MATERIAL THAT IS SMOOTH AND EASILY CLEANABLE.',
#   '51. PLUMBING INSTALLED; PROPER BACKFLOW DEVICES - Comments: OBSERVED A SLOW DRAINAGE AT THE HANDWASHING SINK IN THE BASEMENT PREP AREA. INSTRUCTED TO REPAIR AND MAINTAIN.'],
#  ['36. THERMOMETERS PROVIDED & ACCURATE - Comments: OBSERVED NO AMBIANT AIR THERMOMETER INSIDE DISPLAY COOLER CONTAIN SODA POPS. I INSTRUCTED TO PROVIDE. ',
#   '37. FOOD PROPERLY LABELED; ORIGINAL CONTAINER - Comments: OBSERVED NO LABEL ON PACKAGED FOOD ITEM (CAKE SLICES). INSTRUCTED TO PROVIDE LABELS ON ALL PACKAGED FOOD ITEMS WITH IDENTITY, NET WEIGHT, INGREDIENTS, BUSINESS NAME AND ADDRESS WHERE MADE AND PACKAGED.         ',
#   '39. CONTAMINATION PREVENTED DURING FOOD PREPARATION, STORAGE & DISPLAY - Comments: OBSERVED FOOD CONTAINERS STORED ON THE FLOOR IN THE WALK-IN COOLER. INSTRUCTED TO PROPERLY STORE BY ELEVATING AT LEAST SIX INCHES FROM THE FLOOR ON RAISED SHELVING UNITS. ',
#   '47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE, PROPERLY DESIGNED, CONSTRUCTED & USED - Comments: OBSERVED FOOD ITEMS (CHICKEN) STORED IN PLASTIC GROCERY BAGS IN THE WALK IN COOLER AND DEEP FREEZER. INSTRUCTED TO USE PROPER FOOD GRADE STORAGE BAGS AND CONTAINERS ONLY. ',
#   '48. WAREWASHING FACILITIES: INSTALLED, MAINTAINED & USED; TEST STRIPS - Comments: OBSERVED FACILITY WITH NO CHEMICAL TEST KIT. INSTRUCTED TO PROVIDE.  PRIORITY FOUNDATION VIOLATION. 7-38-005. CITATION ISSUED.',
#   '55. PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN - Comments: OBSERVED IMPROPER STORAGE OF MOP IN THE UTILITY SINK/CLOSET AREA. INSTRUCTED TO STORE PROPERLY.',
#   '56. ADEQUATE VENTILATION & LIGHTING; DESIGNATED AREAS USED - Comments: OBSERVED NO LIGHT BULB COVER IN UTILITY CLOSET AREA. INSTRUCTED TO PROVIDE.',
#   '57. ALL FOOD EMPLOYEES HAVE FOOD HANDLER TRAINING - Comments: OBSERVED NO FOOD HANDLERS TRAINING CERTIFICATE FOR FOOD HANDLER. INSTRUCTED TO PROVIDE.'],
#  ['53. TOILET FACILITIES: PROPERLY CONSTRUCTED, SUPPLIED, & CLEANED - Comments: MUST PROVIDE AND MAINTAIN A SELF CLOSING DEVICE ON THE WASHROOM DOOR.'],
#  ['10. ADEQUATE HANDWASHING SINKS PROPERLY SUPPLIED AND ACCESSIBLE - Comments: NOTED NO HANDWASH SIGNAGE AT NORTH WASHROOM. INSTRUCTED TO PROVIDE AND MAINTAIN',
#   '23. PROPER DATE MARKING AND DISPOSITION - Comments: OBSERVED TCS FOODS CUT AVOCADO, ARTICHOKE, COOKED CHICKEN BREAST, SLICED TOMATOES, SLICED ONIONS, SLICED PICKLES, WITH DISCARD DATES OF 03/25/25 IN FRONT SANDWICH TOPPINGS DELI COOLER. PERSON IN CHARGE DISCARDED AND DENATURED APPROXIMATELY 10 LBS VALUED AT $33 PRIORITY VIOLATION. 7-38-005. CITATION ISSUED.',
#   '47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE, PROPERLY DESIGNED, CONSTRUCTED & USED - Comments: NOTED CUTTING BOARD ON SMALL DELI COOLER WITH DEEP CUTS AND STAINS, INSTRUCTED TO RESTORE TO A SMOOTH AND EASY TO CLEAN SURFACE BY DEEP CLEANING, SANDING AND SEALING OR REPLACE AND MAINTAIN.',
#   '55. PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN - Comments: OBSERVED ENCRUSTED GREASE AND GRIME ON FLOOR UNDERNEATH 3 COMPARTMENT SINK BEHIND GREASE TRAP, INSTRUCTED TO CLEAN AND MAINTAIN'],
#  ['3. MANAGEMENT, FOOD EMPLOYEE AND CONDITIONAL EMPLOYEE; KNOWLEDGE, RESPONSIBILITIES AND REPORTING - Comments: 2-102.14(O) - OBSERVED NO WRITTEN EMPLOYEE HEALTH POLICY ON THE PREMISES.INSTRUCTED TO PROVIDE A SIGNED EMPLOYEE HEALTH POLICY FOR EACH EMPLOYEE AND MAINTAIN AS REQUIRED. PRIORITY FOUNDATION VIOLATION 7-38-010.',
#   '21. PROPER HOT HOLDING TEMPERATURES - Comments: OBSERVED COOKED CHICKEN, COOKED GRAVY, AND FRIED CHICKEN TO BE STORED ON THE COUNTER AT 90.2F, 100F, AND 68.3F, RESEPECTIVELY, WITH NO ACTIVE SOURCE OF TEMPERATURE REGULATION. ALL IMPROPERLY HOT HELD FOOD WAS DISCARDED AND DENATURED AT TIME OF INSPECTION. APPROXIMATELY 30LBS OF FOOD VALUED AT $100 DISCARDED. PRIORITY VIOLATION, 7-38-005. CITATION ISSUED. ',
#   '35. APPROVED THAWING METHODS USED - Comments: OBSERVED VARIOUS POTS OF CHICKEN, BEEF, AND FISH THAWING AT ROOM TEMPERATURE ON PREP TABLES NEXT TO 3 COMPARTMENT SINK. INSTRUCTED MANAGER TO APPROPRIATELY THAW FROZEN MEATS UNDER REFRIGERATION, COMPLETELY SUBMERGED UNDER RUNNING WATER, DURING COOKING PROCESS, ETC. ',
#   '44. UTENSILS, EQUIPMENT & LINENS: PROPERLY STORED, DRIED, & HANDLED - Comments:  4-903.11 (A;B;D) - OBSERVED FOOD SERVICE EQUIPMENT (HOT HOLDING EQUIPMENT) STORED BENEATH UNPROTECTED/NOT SHIELDED WASTEWATER AND SEWER LINES IN THE BASEMENT STORAGE IN REAR CORNER NEXT TO GREASE TRAP. INSTRUCTED MANAGER TO PROVIDE APPROPRIATE SHIELDING OR MOVE ALL FOOD ITEMS AND STORAGE BINS FROM BELOW ANY UNPROTECTED SEWER AND WASTEWATER LINES.',
#   '47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE, PROPERLY DESIGNED, CONSTRUCTED & USED - Comments: 4-501.11 - OBSERVED DOOR OF SINGLE FRYER TO BE EXTREMELY LOOSE FROM ITS HINGES, ALMOST FALLING OFF WHEN OPENED. INSTRUCTED TO SERVICE AND MAINTAIN ALL EQUIPMENT IN GOOD REPAIR.',
#   '47. FOOD & NON-FOOD CONTACT SURFACES CLEANABLE, PROPERLY DESIGNED, CONSTRUCTED & USED - Comments: 4-101.19 - OBSERVED PREP TABLE NEXT TO 1 COMP SINK WITH UNIFINISHED/DAMAGED WOODEN TICKET/ORDER HOLDERS ATTACHED TO SHELVES. INSTRUCTED MANAGER TO REPAIR AND SEAL ALL WOODEN ITEMS IN OR PROVIDE A REPLACEMENT THAT IS SMOOTH, EASILY CLEANABLE, AND NONABSORBENT.',
#   '49. NON-FOOD/FOOD CONTACT SURFACES CLEAN - Comments: OBSERVED INTERIOR OF MICROWAVE ON PREP LINE ACROSS DISH MACHINE TO BE HEAVILY SOILED ON ALL WALLS AND UPPER SURFACE AT TIME OF INSPECTION. INSTRUCTED TO CLEAN AND MAINTAIN FREE OF EXCESSIVE GREAVE AND FOOD DEBRIS BUILD UP. ',
#   '55. PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN - Comments: OBSERVED DOUGH EQUIPMENT, FRYER, TABLES, AND SHELF STORED OUTSIDE ON BACK PORCH UNDER 2ND FLOOR STAIRS. INSTRUCTED MANAGER TO REMOVE ALL UNNECESSARY ITEMS TO FACILITY OPERATION OR STORE APPROPRIATELY WHEN NOT IN USE. MANAGER PLACED ALL EQUIPMENT INSIDE AT TIME OF INSPECTION. ',
#   '55. PHYSICAL FACILITIES INSTALLED, MAINTAINED & CLEAN - Comments: 6-201.13 - OBSERVED 3 AREAS AROUND PIPES IN MOP SINK CLOSET TO HAVE MISSING COVING PRESENT AROUND PIPE SAT TIME OF INSPECTION. INSTRUCTED MANAGER TO REPLACE/PROVIDE APPROPRIATE COVING/COVER FOR ALL GAPS.',
#   '56. ADEQUATE VENTILATION & LIGHTING; DESIGNATED AREAS USED - Comments: 6-303.11 - OBSERVED LIGHT IN HALL OUTSIDE OF BOTH BATHROOMS TO NOT BE ON AND FUNCTIONAL AT TIME OF INSPECTION. OBSERVED LIGHT IN 2 DOOR STANDING FREEZER TO NOT BE WORKING AT TIME OF INSPECTION. INSTRUCTED MANAGER TO SERVICE LIGHT AND REPAIR TO PROVIDE ADEQUATE LIGHTING IN HALL AND STANDING 2 DOOR FREEZER.',
#   '56. ADEQUATE VENTILATION & LIGHTING; DESIGNATED AREAS USED - Comments: 6-202.11 - OBSERVED ONE LIGHT IN EXHAUST HOOD TO HAVE MISSING PROTECTIVE SHIELDING AT TIME OF INSPECTION. INSTRUCTED MANAGER TO REPLACE AND PROVIDE ADEQUATE PROTECTIVE SHEILDING AT ALL LIGHTS IN KITCHEN AND PREP AREAS.',
#   '61. SUMMARY REPORT DISPLAYED AND VISIBLE TO THE PUBLIC - Comments: OBSERVED NO SUMMARY REPORT FROM MOST RECENT INSPECTION ON 3/6/2025, REPORT #2613269 POSTED IN PLAIN VIEW OF PUBLIC AT TIME OF INSPECTION. INSTRUCTED MANAGER TO ENSURE SUMMARY REPORT IS POSTED AND AVAILABLE IN PLAIN VIEW OF PUBLIC AT ALL TIMES. NEW SUMMARY REPORT PROVIDED AT TIME OF INSPECTION FOR CURRENT INSPECTION. PRIORITY FOUNDATION VIOLATION, 7-42-010(b). CITATION ISSUED.'],
#  ...]

# %%
violation_number_list = []
import re

for violation in df["violations_list"]:
    number_list = []
    for v in violation:
        match = re.match(r"^\d+", v)  # Extract leading numbers
        if match:
            number_list.append(match.group())  # Append extracted violation number
    
    violation_number_list.append(number_list)  # Store numbers for the entity
df["violation_num_list"] = violation_number_list

# %%
# Check if there are any rows left with missing ZIP codes
missing_zip_count_after = df['license_'].isna().sum()
print(f"Number of missing License # after dropping rows: {missing_zip_count_after}")
# Out:
# Number of missing License # after dropping rows: 0

# %%
print("Null values count:")
print("dba_name:", df['inspection_type'].isnull().sum())
# Out:
# Null values count:
# dba_name: 0

# %%
unique_counts = df['results'].value_counts()
print(unique_counts)
# Out:
# results
# Pass                  149097
# Fail                   55683
# Pass w/ Conditions     43551
# No Entry               12173
# Not Ready               3657
# Name: count, dtype: int64

# %%
unique_counts = df['inspection_type'].value_counts()
print(unique_counts)
# Out:
# inspection_type
# Canvass                          126445
# License                           38023
# Canvass Re-Inspection             32159
# Complaint                         26944
# License Re-Inspection             12022
#                                   ...
# SFP RECENTLY INSPECTED                1
# SMOKING COMPLAINT                     1
# Recent inspection                     1
# expansion                             1
# TASK FORCE PACKAGE GOODS 1474         1
# Name: count, Length: 105, dtype: int64

# %%
# Display the first few rows of the DataFrame
print(df.head())
# Out:
#    inspection_id                   dba_name                   aka_name  \
# 0        2616252  ROTI MODERN MEDITERRANEAN  ROTI MODERN MEDITERRANEAN
# 1        2616253     MAGGIE GYROS & CHICKEN     MAGGIE GYROS & CHICKEN
# 2        2616226    FORNO ROSSO ON RANDOLPH    FORNO ROSSO ON RANDOLPH
# 4        2616171          TO KOREAN CUISINE          TO KOREAN CUISINE
# 6        2616216                 PUP SOCIAL                 PUP SOCIAL
#
#    license_ facility_type           risk             address     city state  \
# 0   2594670    Restaurant  Risk 1 (High)  1012 W RANDOLPH ST  Chicago    IL
# 1   1869774    Restaurant  Risk 1 (High)       349 E 47TH ST  Chicago    IL
# 2   2358717    Restaurant  Risk 1 (High)  1048 W RANDOLPH ST  Chicago    IL
# 4   2997283    Restaurant  Risk 1 (High)     3108 N BROADWAY  Chicago    IL
# 6   2997708        Liquor   Risk 3 (Low)  2200 N ASHLAND AVE  Chicago    IL
#
#      zip inspection_date inspection_type   results   latitude  longitude  \
# 0  60607      2025-04-23         Canvass      Pass  41.884426 -87.652690
# 1  60653      2025-04-23       Complaint  No Entry  41.809257 -87.617666
# 2  60607      2025-04-23         Canvass      Pass  41.884401 -87.654031
# 4  60657      2025-04-22         Canvass      Pass  41.937940 -87.644477
# 6  60614      2025-04-22         License      Fail  41.921585 -87.668773
#
#                                           violations facility_type_clean  \
# 0                                                             restaurant
# 1                                                             restaurant
# 2  55. PHYSICAL FACILITIES INSTALLED, MAINTAINED ...          restaurant
# 4  37. FOOD PROPERLY LABELED; ORIGINAL CONTAINER ...          restaurant
# 6  3. MANAGEMENT, FOOD EMPLOYEE AND CONDITIONAL E...              liquor
#
#                                      violations_list  \
# 0                                                 []
# 1                                                 []
# 2  [55. PHYSICAL FACILITIES INSTALLED, MAINTAINED...
# 4  [37. FOOD PROPERLY LABELED; ORIGINAL CONTAINER...
# 6  [3. MANAGEMENT, FOOD EMPLOYEE AND CONDITIONAL ...
#
#                         violation_num_list
# 0                                       []
# 1                                       []
# 2                                     [55]
# 4                                 [37, 54]
# 6  [3, 10, 38, 38, 52, 53, 53, 55, 55, 55]

# %%
null_counts = df.isnull().sum()
print("Null values in each column:")
print(null_counts)
# Out:
# Null values in each column:
# inspection_id          0
# dba_name               0
# aka_name               0
# license_               0
# facility_type          0
# risk                   0
# address                0
# city                   0
# state                  0
# zip                    0
# inspection_date        0
# inspection_type        0
# results                0
# latitude               0
# longitude              0
# violations             0
# facility_type_clean    0
# violations_list        0
# violation_num_list     0
# dtype: int64

# %%
count = ((df['results'] == 'Fail') & (df['violations'].isnull())).sum()
print("Number of 'Fail' rows with missing violations:", count)
# Out:
# Number of 'Fail' rows with missing violations: 0

# %%
df.to_csv('data/cleaned_chicago_data.csv', index=False)
